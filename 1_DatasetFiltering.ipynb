# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/WBS, IKT KG Project/data/PMC-Patients.csv", index_col="patient_id")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167034 entries, 0 to 167033
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   patient_uid        167034 non-null  object
#  1   PMID               167034 non-null  int64
#  2   file_path          167034 non-null  object
#  3   title              167034 non-null  object
#  4   patient            167034 non-null  object
#  5   age                167034 non-null  object
#  6   gender             167034 non-null  object
#  7   relevant_articles  167034 non-null  object
#  8   similar_patients   167034 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 12.7+ MB

# %%
title_counts = df['title'].value_counts()

# %%
top_titles = title_counts.head(2000).index

# %%
filtered_df = df[df['title'].isin(top_titles)]

# %%
len(filtered_df)
# Out:
# 10534

# %%
filtered_df
# Out:
#            patient_uid      PMID                            file_path  \
# patient_id
# 0            7665777-1  33492400     comm/PMC007xxxxxx/PMC7665777.xml
# 1            7665777-2  33492400     comm/PMC007xxxxxx/PMC7665777.xml
# 2            7665777-3  33492400     comm/PMC007xxxxxx/PMC7665777.xml
# 3            7665777-4  33492400     comm/PMC007xxxxxx/PMC7665777.xml
# 4            7665777-5  33492400     comm/PMC007xxxxxx/PMC7665777.xml
# ...                ...       ...                                  ...
# 166970       3999607-1  24778675  noncomm/PMC003xxxxxx/PMC3999607.xml
# 166971       3999607-2  24778675  noncomm/PMC003xxxxxx/PMC3999607.xml
# 166972       3999607-3  24778675  noncomm/PMC003xxxxxx/PMC3999607.xml
# 166973       3999607-4  24778675  noncomm/PMC003xxxxxx/PMC3999607.xml
# 166974       3999607-5  24778675  noncomm/PMC003xxxxxx/PMC3999607.xml
#
#                                                         title  \
# patient_id
# ...

# %%
filtered_df.to_csv("/content/drive/MyDrive/FINKI/WBS, IKT KG Project/data/patients_filtered.csv")
